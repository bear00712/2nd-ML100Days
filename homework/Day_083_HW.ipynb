# %% [markdown]
# ## Work
# 1. 試比較有 BN 在 Batch_size = 2, 16, 32, 128, 256 下的差異
# 2. 請嘗試將 BN 放在 Activation 之前，並比較訓練結果
# 3. 請於 BN 放在 Input Layer 後，並比較結果

# %%
import os
import keras
import itertools
# Disable GPU
# Out:
# Using TensorFlow backend.

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import BatchNormalization, Activation
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128], pre_activate=False):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   name="hidden_layer"+str(i+1))(input_layer)
            if pre_activate:
                x = BatchNormalization()(x)
                x = Activation("relu")(x)
            else:
                x = Activation("relu")(x)
                x = BatchNormalization()(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   name="hidden_layer"+str(i+1))(x)
            if pre_activate:
                x = BatchNormalization()(x)
                x = Activation("relu")(x)
            else:
                x = Activation("relu")(x)
                x = BatchNormalization()(x)
                
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
"""Code Here
設定超參數
"""

LEARNING_RATE = 1e-3
EPOCHS = 25
BATCH_SIZE = [ 32, 128, 256]
PRE_ACTIVATE = [True, False]
MOMENTUM = 0.95

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
results = {}
"""Code Here
撰寫你的訓練流程並將結果用 dictionary 紀錄
"""
for i, (use_preact, bz) in enumerate(itertools.product(PRE_ACTIVATE, BATCH_SIZE)):
    print("Numbers of exp: %i, use_preact: %s, batch_size: %i" % (i, use_preact, bz))
    model = build_mlp(input_shape=x_train.shape[1:], pre_activate=use_preact)
    model.summary()
    optimizer = keras.optimizers.Adam(lr=LEARNING_RATE)
    model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

    model.fit(x_train, y_train, 
              epochs=EPOCHS, 
              batch_size=bz, 
              validation_data=(x_test, y_test), 
              verbose=1,
              shuffle=True)
    
    # Collect results
    train_loss = model.history.history["loss"]
    valid_loss = model.history.history["val_loss"]
    train_acc = model.history.history["acc"]
    valid_acc = model.history.history["val_acc"]
    exp_name_tag = ("exp-%s" % (i))
    results[exp_name_tag] = {'train-loss': model.history.history["loss"],
                             'valid-loss': model.history.history["val_loss"],
                             'train-acc': model.history.history["acc"],
                             'valid-acc': model.history.history["val_acc"]}
    
    plt.plot(range(len(train_loss)), train_loss, label="train loss")
    plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
    plt.legend()
    plt.title("Loss")
    plt.show()

    plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
    plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
    plt.legend()
    plt.title("Accuracy")
    plt.show()
# Out:
# Numbers of exp: 0, use_preact: True, batch_size: 32
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 512)               2048
# _________________________________________________________________
# activation_4 (Activation)    (None, 512)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_5 (Activation)    (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 128)               512
# _________________________________________________________________
# activation_6 (Activation)    (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/25
# 50000/50000 [==============================] - 18s 359us/step - loss: 1.6606 - acc: 0.4055 - val_loss: 1.6984 - val_acc: 0.3934
# Epoch 2/25
# 50000/50000 [==============================] - 17s 348us/step - loss: 1.4557 - acc: 0.4807 - val_loss: 1.6726 - val_acc: 0.4125
# Epoch 3/25
# 50000/50000 [==============================] - 18s 352us/step - loss: 1.3543 - acc: 0.5171 - val_loss: 1.7592 - val_acc: 0.4003
# Epoch 4/25
# 50000/50000 [==============================] - 16s 312us/step - loss: 1.2795 - acc: 0.5438 - val_loss: 1.4936 - val_acc: 0.4692
# Epoch 5/25
# 50000/50000 [==============================] - 16s 318us/step - loss: 1.2152 - acc: 0.5657 - val_loss: 1.4297 - val_acc: 0.4944
# Epoch 6/25
# 50000/50000 [==============================] - 20s 394us/step - loss: 1.1525 - acc: 0.5869 - val_loss: 1.4681 - val_acc: 0.4896
# Epoch 7/25
# 50000/50000 [==============================] - 18s 359us/step - loss: 0.8945 - acc: 0.6797 - val_loss: 1.4317 - val_acc: 0.5151
# Epoch 12/25
# 50000/50000 [==============================] - 15s 305us/step - loss: 0.8518 - acc: 0.6958 - val_loss: 1.5777 - val_acc: 0.4897
# Epoch 13/25
# 50000/50000 [==============================] - 15s 299us/step - loss: 0.8027 - acc: 0.7142 - val_loss: 1.6966 - val_acc: 0.4800
# Epoch 14/25
# 50000/50000 [==============================] - 15s 310us/step - loss: 0.7635 - acc: 0.7268 - val_loss: 1.6991 - val_acc: 0.4746
# Epoch 15/25
# 50000/50000 [==============================] - 17s 333us/step - loss: 0.7236 - acc: 0.7434 - val_loss: 1.5488 - val_acc: 0.5154
# Epoch 16/25
# 50000/50000 [==============================] - 16s 312us/step - loss: 0.6911 - acc: 0.7513 - val_loss: 1.5983 - val_acc: 0.5080
# Epoch 17/25
# 50000/50000 [==============================] - 15s 298us/step - loss: 0.6562 - acc: 0.7639 - val_loss: 1.8038 - val_acc: 0.4977
# Epoch 18/25
# 50000/50000 [==============================] - 15s 306us/step - loss: 0.6220 - acc: 0.7761 - val_loss: 1.8447 - val_acc: 0.4796
# Epoch 19/25
# 50000/50000 [==============================] - 16s 320us/step - loss: 0.5958 - acc: 0.7876 - val_loss: 1.8081 - val_acc: 0.4887
# Epoch 20/25
# 50000/50000 [==============================] - 17s 344us/step - loss: 0.5690 - acc: 0.7994 - val_loss: 1.7068 - val_acc: 0.5214
# Epoch 21/25
# 50000/50000 [==============================] - 15s 301us/step - loss: 0.5447 - acc: 0.8094 - val_loss: 1.9879 - val_acc: 0.4848
# Epoch 22/25
# 50000/50000 [==============================] - 16s 320us/step - loss: 0.5165 - acc: 0.8153 - val_loss: 1.9141 - val_acc: 0.4877
# Epoch 23/25
# 50000/50000 [==============================] - 15s 291us/step - loss: 0.5004 - acc: 0.8221 - val_loss: 2.0902 - val_acc: 0.4782
# Epoch 24/25
# 50000/50000 [==============================] - 16s 321us/step - loss: 0.4763 - acc: 0.8298 - val_loss: 1.9814 - val_acc: 0.4911
# Epoch 25/25
# 50000/50000 [==============================] - 15s 301us/step - loss: 0.4578 - acc: 0.8354 - val_loss: 1.7936 - val_acc: 0.5229
# Numbers of exp: 1, use_preact: True, batch_size: 128
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 512)               2048
# _________________________________________________________________
# activation_7 (Activation)    (None, 512)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_8 (Activation)    (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 128)               512
# _________________________________________________________________
# activation_9 (Activation)    (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/25
# 50000/50000 [==============================] - 6s 128us/step - loss: 1.6141 - acc: 0.4287 - val_loss: 2.0795 - val_acc: 0.2838
# Epoch 2/25
# 50000/50000 [==============================] - 6s 114us/step - loss: 1.3816 - acc: 0.5095 - val_loss: 1.7876 - val_acc: 0.3572
# Epoch 3/25
# 50000/50000 [==============================] - 6s 112us/step - loss: 1.2597 - acc: 0.5523 - val_loss: 1.6591 - val_acc: 0.4039
# Epoch 4/25
# 50000/50000 [==============================] - 5s 108us/step - loss: 1.1722 - acc: 0.5829 - val_loss: 1.6761 - val_acc: 0.3914
# Epoch 5/25
# 50000/50000 [==============================] - 5s 99us/step - loss: 1.0871 - acc: 0.6122 - val_loss: 1.5770 - val_acc: 0.4457
# Epoch 6/25
# 50000/50000 [==============================] - 5s 100us/step - loss: 1.0172 - acc: 0.6393 - val_loss: 1.7062 - val_acc: 0.4402
# Epoch 7/25
# 50000/50000 [==============================] - 5s 97us/step - loss: 0.9454 - acc: 0.6665 - val_loss: 2.1006 - val_acc: 0.3695
# Epoch 8/25
# 50000/50000 [==============================] - 5s 109us/step - loss: 0.8738 - acc: 0.6900 - val_loss: 1.6571 - val_acc: 0.4490
# Epoch 9/25
# 50000/50000 [==============================] - 6s 126us/step - loss: 0.8079 - acc: 0.7149 - val_loss: 2.0305 - val_acc: 0.3998
# Epoch 10/25
# 50000/50000 [==============================] - 5s 103us/step - loss: 0.7422 - acc: 0.7371 - val_loss: 1.6978 - val_acc: 0.4437
# Epoch 11/25
# 50000/50000 [==============================] - 6s 115us/step - loss: 0.6763 - acc: 0.7615 - val_loss: 1.7700 - val_acc: 0.4618
# Epoch 12/25
# 50000/50000 [==============================] - 5s 106us/step - loss: 0.6163 - acc: 0.7842 - val_loss: 1.9508 - val_acc: 0.4190
# Epoch 13/25
# 50000/50000 [==============================] - 5s 99us/step - loss: 0.5642 - acc: 0.8021 - val_loss: 2.0292 - val_acc: 0.4368
# Epoch 14/25
# 50000/50000 [==============================] - 5s 101us/step - loss: 0.5027 - acc: 0.8242 - val_loss: 2.2359 - val_acc: 0.4480
# Epoch 15/25
# 50000/50000 [==============================] - 5s 106us/step - loss: 0.4544 - acc: 0.8412 - val_loss: 2.4140 - val_acc: 0.4304
# Epoch 16/25
# 50000/50000 [==============================] - 5s 101us/step - loss: 0.4133 - acc: 0.8560 - val_loss: 2.1158 - val_acc: 0.4709
# Epoch 17/25
# 50000/50000 [==============================] - 5s 108us/step - loss: 0.3760 - acc: 0.8688 - val_loss: 2.9681 - val_acc: 0.4026
# Epoch 18/25
# 50000/50000 [==============================] - 5s 90us/step - loss: 0.3367 - acc: 0.8828 - val_loss: 2.6179 - val_acc: 0.4331
# Epoch 19/25
# 50000/50000 [==============================] - 5s 103us/step - loss: 0.3187 - acc: 0.8887 - val_loss: 2.5547 - val_acc: 0.4486
# Epoch 20/25
# 50000/50000 [==============================] - 5s 101us/step - loss: 0.2836 - acc: 0.9001 - val_loss: 2.3553 - val_acc: 0.4680
# Epoch 21/25
# 50000/50000 [==============================] - 5s 102us/step - loss: 0.2676 - acc: 0.9059 - val_loss: 2.6834 - val_acc: 0.4442
# Epoch 22/25
# 50000/50000 [==============================] - 5s 103us/step - loss: 0.2397 - acc: 0.9178 - val_loss: 3.4277 - val_acc: 0.4178
# Epoch 23/25
# 50000/50000 [==============================] - 5s 108us/step - loss: 0.2294 - acc: 0.9205 - val_loss: 2.9912 - val_acc: 0.4225
# Epoch 24/25
# 50000/50000 [==============================] - 5s 98us/step - loss: 0.2197 - acc: 0.9237 - val_loss: 2.7091 - val_acc: 0.4714
# Epoch 25/25
# 50000/50000 [==============================] - 5s 106us/step - loss: 0.2118 - acc: 0.9254 - val_loss: 3.0211 - val_acc: 0.4374
# Numbers of exp: 2, use_preact: True, batch_size: 256
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 512)               2048
# _________________________________________________________________
# activation_10 (Activation)   (None, 512)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_11 (Activation)   (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 128)               512
# _________________________________________________________________
# activation_12 (Activation)   (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/25
# 50000/50000 [==============================] - 4s 80us/step - loss: 1.6110 - acc: 0.4271 - val_loss: 2.0763 - val_acc: 0.3054
# Epoch 2/25
# 50000/50000 [==============================] - 3s 52us/step - loss: 1.3696 - acc: 0.5127 - val_loss: 1.7761 - val_acc: 0.3592
# Epoch 3/25
# 50000/50000 [==============================] - 3s 58us/step - loss: 1.2460 - acc: 0.5548 - val_loss: 1.8153 - val_acc: 0.3888
# Epoch 4/25
# 50000/50000 [==============================] - 3s 53us/step - loss: 1.1488 - acc: 0.5934 - val_loss: 2.0017 - val_acc: 0.3200
# Epoch 5/25
# 50000/50000 [==============================] - 3s 57us/step - loss: 1.0613 - acc: 0.6238 - val_loss: 1.6355 - val_acc: 0.4158
# Epoch 6/25
# 50000/50000 [==============================] - 3s 61us/step - loss: 0.9905 - acc: 0.6492 - val_loss: 1.6508 - val_acc: 0.4437
# Epoch 7/25
# 50000/50000 [==============================] - 3s 57us/step - loss: 0.9121 - acc: 0.6788 - val_loss: 1.9330 - val_acc: 0.3877
# Epoch 8/25
# 50000/50000 [==============================] - 3s 57us/step - loss: 0.8391 - acc: 0.7041 - val_loss: 1.7052 - val_acc: 0.4271
# Epoch 9/25
# 50000/50000 [==============================] - 3s 53us/step - loss: 0.7723 - acc: 0.7289 - val_loss: 1.8367 - val_acc: 0.4156
# Epoch 10/25
# 50000/50000 [==============================] - 3s 56us/step - loss: 0.7056 - acc: 0.7515 - val_loss: 1.8005 - val_acc: 0.4203
# Epoch 11/25
# 50000/50000 [==============================] - 3s 53us/step - loss: 0.6305 - acc: 0.7797 - val_loss: 2.0351 - val_acc: 0.4227
# Epoch 12/25
# 50000/50000 [==============================] - 3s 56us/step - loss: 0.5685 - acc: 0.8012 - val_loss: 2.2407 - val_acc: 0.4123
# Epoch 13/25
# 50000/50000 [==============================] - 3s 56us/step - loss: 0.5091 - acc: 0.8233 - val_loss: 2.3339 - val_acc: 0.4177
# Epoch 14/25
# 50000/50000 [==============================] - 3s 54us/step - loss: 0.4505 - acc: 0.8444 - val_loss: 2.5105 - val_acc: 0.3979
# Epoch 15/25
# 50000/50000 [==============================] - 2s 49us/step - loss: 0.4090 - acc: 0.8577 - val_loss: 2.0051 - val_acc: 0.4780
# Epoch 16/25
# 50000/50000 [==============================] - 3s 52us/step - loss: 0.3642 - acc: 0.8746 - val_loss: 2.0890 - val_acc: 0.4703
# Epoch 17/25
# 50000/50000 [==============================] - 3s 54us/step - loss: 0.3187 - acc: 0.8926 - val_loss: 2.5314 - val_acc: 0.4145
# Epoch 18/25
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.2905 - acc: 0.9003 - val_loss: 2.6013 - val_acc: 0.4513
# Epoch 19/25
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.2685 - acc: 0.9092 - val_loss: 2.4187 - val_acc: 0.4679
# Epoch 20/25
# 50000/50000 [==============================] - 3s 54us/step - loss: 0.2250 - acc: 0.9242 - val_loss: 2.8382 - val_acc: 0.4325
# Epoch 21/25
# 50000/50000 [==============================] - 3s 56us/step - loss: 0.2019 - acc: 0.9332 - val_loss: 2.8130 - val_acc: 0.4574
# Epoch 22/25
# 50000/50000 [==============================] - 3s 59us/step - loss: 0.1928 - acc: 0.9342 - val_loss: 3.0279 - val_acc: 0.4169
# Epoch 23/25
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.1851 - acc: 0.9367 - val_loss: 2.9320 - val_acc: 0.4427
# Epoch 24/25
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.1781 - acc: 0.9396 - val_loss: 2.7870 - val_acc: 0.4706
# Epoch 25/25
# 50000/50000 [==============================] - 3s 54us/step - loss: 0.1688 - acc: 0.9426 - val_loss: 2.7931 - val_acc: 0.4620
# Numbers of exp: 3, use_preact: False, batch_size: 32
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# activation_13 (Activation)   (None, 512)               0
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# activation_14 (Activation)   (None, 256)               0
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# activation_15 (Activation)   (None, 128)               0
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/25
# 50000/50000 [==============================] - 16s 325us/step - loss: 1.7503 - acc: 0.3772 - val_loss: 1.7708 - val_acc: 0.3653
# Epoch 2/25
# 50000/50000 [==============================] - 15s 299us/step - loss: 1.5856 - acc: 0.4345 - val_loss: 1.5979 - val_acc: 0.4315
# Epoch 3/25
# 50000/50000 [==============================] - 15s 302us/step - loss: 1.5077 - acc: 0.4617 - val_loss: 1.5138 - val_acc: 0.4701
# Epoch 4/25
# 50000/50000 [==============================] - 16s 322us/step - loss: 1.4468 - acc: 0.4843 - val_loss: 1.4506 - val_acc: 0.4764
# Epoch 5/25
# 50000/50000 [==============================] - 19s 378us/step - loss: 1.3975 - acc: 0.5026 - val_loss: 1.6723 - val_acc: 0.4254
# Epoch 6/25
# 50000/50000 [==============================] - 16s 319us/step - loss: 1.3613 - acc: 0.5152 - val_loss: 1.4901 - val_acc: 0.4729
# Epoch 7/25
# 50000/50000 [==============================] - 17s 338us/step - loss: 1.3246 - acc: 0.5291 - val_loss: 1.4044 - val_acc: 0.4993
# Epoch 8/25
# 50000/50000 [==============================] - 16s 328us/step - loss: 1.2994 - acc: 0.5376 - val_loss: 1.4538 - val_acc: 0.4873
# Epoch 9/25
# 50000/50000 [==============================] - 16s 327us/step - loss: 1.2719 - acc: 0.5474 - val_loss: 1.4606 - val_acc: 0.4745
# Epoch 10/25
# 50000/50000 [==============================] - 15s 309us/step - loss: 1.2499 - acc: 0.5537 - val_loss: 1.4214 - val_acc: 0.4870
# Epoch 11/25
# 50000/50000 [==============================] - 16s 312us/step - loss: 1.2262 - acc: 0.5650 - val_loss: 1.4662 - val_acc: 0.4823
# Epoch 12/25
# 50000/50000 [==============================] - 16s 312us/step - loss: 1.2073 - acc: 0.5712 - val_loss: 1.4976 - val_acc: 0.4707
# Epoch 13/25
# 50000/50000 [==============================] - 17s 334us/step - loss: 1.1862 - acc: 0.5755 - val_loss: 1.4311 - val_acc: 0.4982
# Epoch 14/25
# 50000/50000 [==============================] - 18s 361us/step - loss: 1.1666 - acc: 0.5828 - val_loss: 1.4013 - val_acc: 0.5078
# Epoch 15/25
# 50000/50000 [==============================] - 17s 334us/step - loss: 1.1578 - acc: 0.5865 - val_loss: 1.4491 - val_acc: 0.4938
# Epoch 16/25
# 50000/50000 [==============================] - 17s 341us/step - loss: 1.1384 - acc: 0.5936 - val_loss: 1.4070 - val_acc: 0.5003
# Epoch 17/25
# 50000/50000 [==============================] - 16s 316us/step - loss: 1.1243 - acc: 0.6009 - val_loss: 1.4668 - val_acc: 0.4900
# Epoch 18/25
# 50000/50000 [==============================] - 18s 369us/step - loss: 1.1118 - acc: 0.6035 - val_loss: 1.3663 - val_acc: 0.5166
# Epoch 19/25
# 50000/50000 [==============================] - 15s 309us/step - loss: 1.1005 - acc: 0.6083 - val_loss: 1.4778 - val_acc: 0.4889
# Epoch 20/25
# 50000/50000 [==============================] - 16s 327us/step - loss: 1.0967 - acc: 0.6079 - val_loss: 1.4954 - val_acc: 0.4747
# Epoch 21/25
# 50000/50000 [==============================] - 17s 342us/step - loss: 1.0852 - acc: 0.6114 - val_loss: 1.3857 - val_acc: 0.5245
# Epoch 22/25
# 50000/50000 [==============================] - 16s 328us/step - loss: 1.0670 - acc: 0.6197 - val_loss: 1.4636 - val_acc: 0.4959
# Epoch 23/25
# 50000/50000 [==============================] - 16s 329us/step - loss: 1.0560 - acc: 0.6242 - val_loss: 1.3966 - val_acc: 0.5136
# Epoch 24/25
# 50000/50000 [==============================] - 15s 303us/step - loss: 1.0415 - acc: 0.6291 - val_loss: 1.3842 - val_acc: 0.5216
# Epoch 25/25
# 50000/50000 [==============================] - 15s 303us/step - loss: 1.0298 - acc: 0.6298 - val_loss: 1.3999 - val_acc: 0.5186
# Numbers of exp: 4, use_preact: False, batch_size: 128
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# activation_16 (Activation)   (None, 512)               0
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# activation_17 (Activation)   (None, 256)               0
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# activation_18 (Activation)   (None, 128)               0
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/25
# 50000/50000 [==============================] - 6s 121us/step - loss: 1.6941 - acc: 0.3992 - val_loss: 1.8927 - val_acc: 0.3444
# Epoch 2/25
# 50000/50000 [==============================] - 4s 89us/step - loss: 1.4911 - acc: 0.4712 - val_loss: 1.5859 - val_acc: 0.4364
# Epoch 3/25
# 50000/50000 [==============================] - 4s 82us/step - loss: 1.4052 - acc: 0.5027 - val_loss: 1.7232 - val_acc: 0.3918
# Epoch 4/25
# 50000/50000 [==============================] - 4s 85us/step - loss: 1.3494 - acc: 0.5200 - val_loss: 1.8426 - val_acc: 0.3689
# Epoch 5/25
# 50000/50000 [==============================] - 4s 88us/step - loss: 1.2878 - acc: 0.5416 - val_loss: 1.5520 - val_acc: 0.4534
# Epoch 6/25
# 50000/50000 [==============================] - 5s 99us/step - loss: 1.2393 - acc: 0.5588 - val_loss: 1.4610 - val_acc: 0.4791
# Epoch 7/25
# 50000/50000 [==============================] - 5s 93us/step - loss: 1.1842 - acc: 0.5781 - val_loss: 1.5132 - val_acc: 0.4774
# Epoch 8/25
# 50000/50000 [==============================] - 5s 98us/step - loss: 1.1435 - acc: 0.5937 - val_loss: 1.6588 - val_acc: 0.4477
# Epoch 9/25
# 50000/50000 [==============================] - 4s 90us/step - loss: 1.1082 - acc: 0.6067 - val_loss: 1.7795 - val_acc: 0.4181
# Epoch 10/25
# 50000/50000 [==============================] - 5s 94us/step - loss: 1.0751 - acc: 0.6188 - val_loss: 1.5992 - val_acc: 0.4479
# Epoch 11/25
# 50000/50000 [==============================] - 5s 96us/step - loss: 1.0406 - acc: 0.6298 - val_loss: 1.5789 - val_acc: 0.4677
# Epoch 12/25
# 50000/50000 [==============================] - 5s 96us/step - loss: 1.0108 - acc: 0.6407 - val_loss: 1.4202 - val_acc: 0.5094
# Epoch 13/25
# 50000/50000 [==============================] - 5s 94us/step - loss: 0.9807 - acc: 0.6506 - val_loss: 2.1709 - val_acc: 0.3722
# Epoch 14/25
# 50000/50000 [==============================] - 5s 97us/step - loss: 0.9554 - acc: 0.6618 - val_loss: 1.7289 - val_acc: 0.4505
# Epoch 15/25
# 50000/50000 [==============================] - 5s 91us/step - loss: 0.9271 - acc: 0.6707 - val_loss: 1.4962 - val_acc: 0.5052
# Epoch 16/25
# 50000/50000 [==============================] - 5s 97us/step - loss: 0.8960 - acc: 0.6816 - val_loss: 1.5736 - val_acc: 0.4892
# Epoch 17/25
# 50000/50000 [==============================] - 5s 101us/step - loss: 0.8754 - acc: 0.6888 - val_loss: 1.6212 - val_acc: 0.4795
# Epoch 18/25
# 50000/50000 [==============================] - 5s 110us/step - loss: 0.8487 - acc: 0.6984 - val_loss: 1.5411 - val_acc: 0.4976
# Epoch 19/25
# 50000/50000 [==============================] - 5s 102us/step - loss: 0.8234 - acc: 0.7076 - val_loss: 1.6659 - val_acc: 0.4643
# Epoch 20/25
# 50000/50000 [==============================] - 5s 104us/step - loss: 0.7964 - acc: 0.7170 - val_loss: 1.6453 - val_acc: 0.4861
# Epoch 21/25
# 50000/50000 [==============================] - 5s 100us/step - loss: 0.7769 - acc: 0.7227 - val_loss: 1.6242 - val_acc: 0.4978
# Epoch 22/25
# 50000/50000 [==============================] - 6s 110us/step - loss: 0.7512 - acc: 0.7319 - val_loss: 1.7665 - val_acc: 0.4838
# Epoch 23/25
# 50000/50000 [==============================] - 5s 97us/step - loss: 0.7278 - acc: 0.7409 - val_loss: 1.7146 - val_acc: 0.4846
# Epoch 24/25
# 50000/50000 [==============================] - 5s 109us/step - loss: 0.7127 - acc: 0.7462 - val_loss: 1.7124 - val_acc: 0.4904
# Epoch 25/25
# 50000/50000 [==============================] - 5s 103us/step - loss: 0.6899 - acc: 0.7534 - val_loss: 1.8076 - val_acc: 0.4845
# Numbers of exp: 5, use_preact: False, batch_size: 256
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# activation_19 (Activation)   (None, 512)               0
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# activation_20 (Activation)   (None, 256)               0
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# activation_21 (Activation)   (None, 128)               0
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/25
# 50000/50000 [==============================] - 5s 91us/step - loss: 1.6951 - acc: 0.4049 - val_loss: 1.6892 - val_acc: 0.4006
# Epoch 2/25
# 50000/50000 [==============================] - 3s 53us/step - loss: 1.4797 - acc: 0.4746 - val_loss: 2.1379 - val_acc: 0.2945
# Epoch 3/25
# 50000/50000 [==============================] - 3s 54us/step - loss: 1.3874 - acc: 0.5064 - val_loss: 1.6514 - val_acc: 0.4134
# Epoch 4/25
# 50000/50000 [==============================] - 3s 60us/step - loss: 1.3156 - acc: 0.5314 - val_loss: 1.7887 - val_acc: 0.3602
# Epoch 5/25
# 50000/50000 [==============================] - 3s 58us/step - loss: 1.2591 - acc: 0.5557 - val_loss: 1.6664 - val_acc: 0.4228
# Epoch 6/25
# 50000/50000 [==============================] - 3s 58us/step - loss: 1.2088 - acc: 0.5743 - val_loss: 1.6369 - val_acc: 0.4177
# Epoch 7/25
# 50000/50000 [==============================] - 3s 53us/step - loss: 1.1592 - acc: 0.5891 - val_loss: 1.6014 - val_acc: 0.4441
# Epoch 8/25
# 50000/50000 [==============================] - 3s 57us/step - loss: 1.1276 - acc: 0.5991 - val_loss: 1.8058 - val_acc: 0.3766
# Epoch 9/25
# 50000/50000 [==============================] - 3s 55us/step - loss: 1.0823 - acc: 0.6172 - val_loss: 1.8725 - val_acc: 0.3720
# Epoch 10/25
# 50000/50000 [==============================] - 3s 54us/step - loss: 1.0486 - acc: 0.6291 - val_loss: 1.7067 - val_acc: 0.4249
# Epoch 11/25
# 50000/50000 [==============================] - 3s 55us/step - loss: 1.0043 - acc: 0.6460 - val_loss: 1.5549 - val_acc: 0.4752
# Epoch 12/25
# 50000/50000 [==============================] - 3s 52us/step - loss: 0.9728 - acc: 0.6568 - val_loss: 1.7719 - val_acc: 0.4379
# Epoch 13/25
# 50000/50000 [==============================] - 3s 52us/step - loss: 0.9389 - acc: 0.6670 - val_loss: 1.7559 - val_acc: 0.4360
# Epoch 14/25
# 50000/50000 [==============================] - 3s 52us/step - loss: 0.9047 - acc: 0.6792 - val_loss: 1.5634 - val_acc: 0.4905
# Epoch 15/25
# 50000/50000 [==============================] - 3s 57us/step - loss: 0.8775 - acc: 0.6873 - val_loss: 1.7052 - val_acc: 0.4585
# Epoch 16/25
# 50000/50000 [==============================] - 3s 51us/step - loss: 0.8442 - acc: 0.6994 - val_loss: 1.6784 - val_acc: 0.4701
# Epoch 17/25
# 50000/50000 [==============================] - 3s 57us/step - loss: 0.8097 - acc: 0.7141 - val_loss: 1.8007 - val_acc: 0.4351
# Epoch 18/25
# 50000/50000 [==============================] - 3s 52us/step - loss: 0.7802 - acc: 0.7246 - val_loss: 1.6604 - val_acc: 0.4975
# Epoch 19/25
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.7524 - acc: 0.7347 - val_loss: 1.7025 - val_acc: 0.4870
# Epoch 20/25
# 50000/50000 [==============================] - 3s 58us/step - loss: 0.7205 - acc: 0.7463 - val_loss: 1.6893 - val_acc: 0.4848
# Epoch 21/25
# 50000/50000 [==============================] - 3s 51us/step - loss: 0.7017 - acc: 0.7505 - val_loss: 3.6252 - val_acc: 0.2706
# Epoch 22/25
# 50000/50000 [==============================] - 3s 61us/step - loss: 0.6706 - acc: 0.7611 - val_loss: 1.7673 - val_acc: 0.4651
# Epoch 23/25
# 50000/50000 [==============================] - 3s 62us/step - loss: 0.6511 - acc: 0.7693 - val_loss: 1.8129 - val_acc: 0.4755
# Epoch 24/25
# 50000/50000 [==============================] - 3s 54us/step - loss: 0.6191 - acc: 0.7793 - val_loss: 1.9311 - val_acc: 0.4640
# Epoch 25/25
# 50000/50000 [==============================] - 3s 53us/step - loss: 0.6000 - acc: 0.7874 - val_loss: 1.8180 - val_acc: 0.4807

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
"""Code Here
將結果繪出
"""
import matplotlib.pyplot as plt
import matplotlib.cm as mplcm
import matplotlib.colors as colors
# %matplotlib inline
NUM_COLORS = 20

color_bar = ['b', 'g', 'r', 'c', 'm', 'y' ]

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-loss'])),results[cond]['train-loss'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-loss'])),results[cond]['valid-loss'], '--', label=cond, color=color_bar[i])
plt.title("Loss")
plt.legend()
plt.show()

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-acc'])),results[cond]['train-acc'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-acc'])),results[cond]['valid-acc'], '--', label=cond, color=color_bar[i])
plt.title("Accuracy")
plt.legend()
plt.show()
