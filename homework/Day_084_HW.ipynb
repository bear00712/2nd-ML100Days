# %% [markdown]
# ## Work
# ### 請結合前面的知識與程式碼，比較不同的 regularization 的組合對訓練的結果與影響：如 dropout, regularizers, batch-normalization 等

# %%
import os
import keras
import itertools
# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""
# Out:
# Using TensorFlow backend.

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import BatchNormalization, Activation, Dropout, regularizers
import keras.backend as K

def build_mlp(input_shape, 
              output_units=10, 
              num_neurons=[512, 256, 128],
              use_bn=True,
              drp_ratio=0.,
              l2_ratio=0.):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   kernel_regularizer=regularizers.l2(l2_ratio),
                                   name="hidden_layer"+str(i+1))(input_layer)

            if use_bn:
                x = BatchNormalization()(x)
            x = Activation("relu")(x)
            x = Dropout(drp_ratio)(x)

        else:
            x = keras.layers.Dense(units=n_units, 
                                   kernel_regularizer=regularizers.l2(l2_ratio),
                                   name="hidden_layer"+str(i+1))(x)
            if use_bn:
                x = BatchNormalization()(x)
            x = Activation("relu")(x)
            x = Dropout(drp_ratio)(x)
            
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
"""Code Here
設定超參數
"""
LEARNING_RATE = 1e-3
EPOCHS = 10
BATCH_SIZE = 256
BN = [True, False]
DROPOUT = [0., 0.2, 0.4]
L2 = [0., 1e-2, 1e-4]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

results = {}
"""Code Here
撰寫你的訓練流程並將結果用 dictionary 紀錄
"""

for i, (bn, dropout, l2) in enumerate(itertools.product(BN, DROPOUT, L2)):
    K.clear_session()
    print("Numbers of exp: %i, with bn: %s, drp_ratio: %.2f, l2_ratio: %.2f" % (i, bn, dropout, l2))
    model = build_mlp(input_shape=x_train.shape[1:], use_bn=bn, drp_ratio=dropout, l2_ratio=l2)
    model.summary()
    optimizer = keras.optimizers.Adam(lr=LEARNING_RATE)
    model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

    model.fit(x_train, y_train, 
              epochs=EPOCHS, 
              batch_size=BATCH_SIZE, 
              validation_data=(x_test, y_test), 
              verbose=1,
              shuffle=True)
    
    # Collect results
    train_loss = model.history.history["loss"]
    valid_loss = model.history.history["val_loss"]
    train_acc = model.history.history["acc"]
    valid_acc = model.history.history["val_acc"]
    exp_name_tag = ("exp-%s" % (i))
    results[exp_name_tag] = {'train-loss': model.history.history["loss"],
                             'valid-loss': model.history.history["val_loss"],
                             'train-acc': model.history.history["acc"],
                             'valid-acc': model.history.history["val_acc"]}
    
    plt.plot(range(len(train_loss)), train_loss, label="train loss")
    plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
    plt.legend()
    plt.title("Loss")
    plt.show()

    plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
    plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
    plt.legend()
    plt.title("Accuracy")
    plt.show()
# Out:
# Numbers of exp: 0, with bn: True, drp_ratio: 0.00, l2_ratio: 0.00
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# activation_1 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_2 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# activation_3 (Activation)    (None, 128)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 5s 108us/step - loss: 1.6234 - acc: 0.4237 - val_loss: 2.1170 - val_acc: 0.2799
# Epoch 2/10
# 50000/50000 [==============================] - 5s 91us/step - loss: 1.3670 - acc: 0.5167 - val_loss: 1.6961 - val_acc: 0.3954
# Epoch 3/10
# 50000/50000 [==============================] - 5s 91us/step - loss: 1.2443 - acc: 0.5580 - val_loss: 1.5772 - val_acc: 0.4240
# Epoch 4/10
# 50000/50000 [==============================] - 5s 91us/step - loss: 1.1534 - acc: 0.5902 - val_loss: 1.8454 - val_acc: 0.3627
# Epoch 5/10
# 50000/50000 [==============================] - 5s 91us/step - loss: 1.0627 - acc: 0.6222 - val_loss: 1.8617 - val_acc: 0.3476
# Epoch 6/10
# 50000/50000 [==============================] - 5s 91us/step - loss: 0.9852 - acc: 0.6517 - val_loss: 1.7781 - val_acc: 0.3987
# Epoch 7/10
# 50000/50000 [==============================] - 5s 91us/step - loss: 0.9125 - acc: 0.6766 - val_loss: 1.9559 - val_acc: 0.3990
# Epoch 8/10
# 50000/50000 [==============================] - 5s 91us/step - loss: 0.8384 - acc: 0.7043 - val_loss: 1.7847 - val_acc: 0.4108
# Epoch 9/10
# 50000/50000 [==============================] - 5s 91us/step - loss: 0.7696 - acc: 0.7307 - val_loss: 1.8717 - val_acc: 0.4156
# Epoch 10/10
# 50000/50000 [==============================] - 5s 92us/step - loss: 0.6974 - acc: 0.7544 - val_loss: 1.7161 - val_acc: 0.4656
# Numbers of exp: 1, with bn: True, drp_ratio: 0.00, l2_ratio: 0.01
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# activation_1 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_2 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# activation_3 (Activation)    (None, 128)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 6s 121us/step - loss: 5.2439 - acc: 0.4038 - val_loss: 2.9354 - val_acc: 0.2137
# Epoch 2/10
# 50000/50000 [==============================] - 5s 100us/step - loss: 2.1024 - acc: 0.4323 - val_loss: 2.5697 - val_acc: 0.2159
# Epoch 3/10
# 50000/50000 [==============================] - 5s 101us/step - loss: 1.9085 - acc: 0.4382 - val_loss: 2.7187 - val_acc: 0.1762
# Epoch 4/10
# 50000/50000 [==============================] - 5s 100us/step - loss: 1.8600 - acc: 0.4452 - val_loss: 2.5183 - val_acc: 0.2303
# Epoch 5/10
# 50000/50000 [==============================] - 5s 100us/step - loss: 1.8325 - acc: 0.4553 - val_loss: 2.8701 - val_acc: 0.2364
# Epoch 6/10
# 50000/50000 [==============================] - 5s 100us/step - loss: 1.8180 - acc: 0.4588 - val_loss: 2.5672 - val_acc: 0.2224
# Epoch 7/10
# 50000/50000 [==============================] - 5s 100us/step - loss: 1.7907 - acc: 0.4627 - val_loss: 2.2133 - val_acc: 0.3114
# Epoch 8/10
# 50000/50000 [==============================] - 5s 99us/step - loss: 1.7736 - acc: 0.4647 - val_loss: 2.1744 - val_acc: 0.3418
# Epoch 9/10
# 50000/50000 [==============================] - 5s 99us/step - loss: 1.7558 - acc: 0.4698 - val_loss: 2.4527 - val_acc: 0.2795
# Epoch 10/10
# 50000/50000 [==============================] - 5s 99us/step - loss: 1.7371 - acc: 0.4744 - val_loss: 2.0790 - val_acc: 0.3403
# Numbers of exp: 2, with bn: True, drp_ratio: 0.00, l2_ratio: 0.00
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# activation_1 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_2 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# activation_3 (Activation)    (None, 128)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 6s 115us/step - loss: 1.7613 - acc: 0.4255 - val_loss: 2.2988 - val_acc: 0.2967
# Epoch 2/10
# 50000/50000 [==============================] - 5s 98us/step - loss: 1.5213 - acc: 0.5108 - val_loss: 1.9882 - val_acc: 0.3434
# Epoch 3/10
# 50000/50000 [==============================] - 5s 100us/step - loss: 1.4068 - acc: 0.5526 - val_loss: 1.8297 - val_acc: 0.3997
# Epoch 4/10
# 50000/50000 [==============================] - 5s 100us/step - loss: 1.3220 - acc: 0.5847 - val_loss: 1.9350 - val_acc: 0.3582
# Epoch 5/10
# 50000/50000 [==============================] - 5s 100us/step - loss: 1.2624 - acc: 0.6079 - val_loss: 1.7478 - val_acc: 0.4252
# Epoch 6/10
# 50000/50000 [==============================] - 5s 99us/step - loss: 1.2052 - acc: 0.6323 - val_loss: 1.8498 - val_acc: 0.4019
# Epoch 7/10
# 50000/50000 [==============================] - 5s 100us/step - loss: 1.1488 - acc: 0.6538 - val_loss: 1.9964 - val_acc: 0.3964
# Epoch 8/10
# 50000/50000 [==============================] - 5s 99us/step - loss: 1.1055 - acc: 0.6706 - val_loss: 1.9268 - val_acc: 0.3953
# Epoch 9/10
# 50000/50000 [==============================] - 5s 96us/step - loss: 1.0659 - acc: 0.6904 - val_loss: 2.2163 - val_acc: 0.3811
# Epoch 10/10
# 50000/50000 [==============================] - 5s 97us/step - loss: 1.0184 - acc: 0.7043 - val_loss: 1.8855 - val_acc: 0.4322
# Numbers of exp: 3, with bn: True, drp_ratio: 0.20, l2_ratio: 0.00
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# activation_1 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_2 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# activation_3 (Activation)    (None, 128)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 6s 110us/step - loss: 1.7910 - acc: 0.3626 - val_loss: 1.9345 - val_acc: 0.3142
# Epoch 2/10
# 50000/50000 [==============================] - 5s 95us/step - loss: 1.5499 - acc: 0.4483 - val_loss: 1.6777 - val_acc: 0.3923
# Epoch 3/10
# 50000/50000 [==============================] - 5s 97us/step - loss: 1.4505 - acc: 0.4826 - val_loss: 1.6032 - val_acc: 0.4348
# Epoch 4/10
# 50000/50000 [==============================] - 5s 96us/step - loss: 1.3818 - acc: 0.5032 - val_loss: 1.5826 - val_acc: 0.4322
# Epoch 5/10
# 50000/50000 [==============================] - 5s 96us/step - loss: 1.3276 - acc: 0.5251 - val_loss: 1.5571 - val_acc: 0.4440
# Epoch 6/10
# 50000/50000 [==============================] - 5s 96us/step - loss: 1.2850 - acc: 0.5414 - val_loss: 1.5246 - val_acc: 0.4533
# Epoch 7/10
# 50000/50000 [==============================] - 5s 96us/step - loss: 1.2412 - acc: 0.5561 - val_loss: 1.5152 - val_acc: 0.4575
# Epoch 8/10
# 50000/50000 [==============================] - 5s 97us/step - loss: 1.2020 - acc: 0.5725 - val_loss: 1.4765 - val_acc: 0.4676
# Epoch 9/10
# 50000/50000 [==============================] - 5s 97us/step - loss: 1.1719 - acc: 0.5814 - val_loss: 1.4448 - val_acc: 0.4907
# Epoch 10/10
# 50000/50000 [==============================] - 5s 97us/step - loss: 1.1423 - acc: 0.5949 - val_loss: 1.4210 - val_acc: 0.4826
# Numbers of exp: 4, with bn: True, drp_ratio: 0.20, l2_ratio: 0.01
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# activation_1 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_2 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# activation_3 (Activation)    (None, 128)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 6s 123us/step - loss: 5.7076 - acc: 0.3506 - val_loss: 2.9409 - val_acc: 0.2136
# Epoch 2/10
# 50000/50000 [==============================] - 5s 106us/step - loss: 2.2766 - acc: 0.3948 - val_loss: 2.4475 - val_acc: 0.3058
# Epoch 3/10
# 50000/50000 [==============================] - 5s 106us/step - loss: 2.0608 - acc: 0.3996 - val_loss: 2.3143 - val_acc: 0.3028
# Epoch 4/10
# 50000/50000 [==============================] - 5s 107us/step - loss: 2.0159 - acc: 0.4065 - val_loss: 2.4234 - val_acc: 0.2419
# Epoch 5/10
# 50000/50000 [==============================] - 5s 102us/step - loss: 1.9976 - acc: 0.4108 - val_loss: 2.4115 - val_acc: 0.2129
# Epoch 6/10
# 50000/50000 [==============================] - 5s 104us/step - loss: 1.9879 - acc: 0.4101 - val_loss: 2.4968 - val_acc: 0.2055
# Epoch 7/10
# 50000/50000 [==============================] - 5s 106us/step - loss: 1.9887 - acc: 0.4137 - val_loss: 2.4501 - val_acc: 0.2365
# Epoch 8/10
# 50000/50000 [==============================] - 5s 106us/step - loss: 1.9723 - acc: 0.4137 - val_loss: 2.4643 - val_acc: 0.1979
# Epoch 9/10
# 50000/50000 [==============================] - 5s 106us/step - loss: 1.9733 - acc: 0.4159 - val_loss: 2.3236 - val_acc: 0.2601
# Epoch 10/10
# 50000/50000 [==============================] - 5s 106us/step - loss: 1.9588 - acc: 0.4206 - val_loss: 2.8065 - val_acc: 0.1848
# Numbers of exp: 5, with bn: True, drp_ratio: 0.20, l2_ratio: 0.00
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# activation_1 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_2 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# activation_3 (Activation)    (None, 128)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 6s 126us/step - loss: 1.9377 - acc: 0.3635 - val_loss: 2.1537 - val_acc: 0.2949
# Epoch 2/10
# 50000/50000 [==============================] - 5s 105us/step - loss: 1.6978 - acc: 0.4444 - val_loss: 1.9702 - val_acc: 0.3395
# Epoch 3/10
# 50000/50000 [==============================] - 5s 107us/step - loss: 1.6031 - acc: 0.4802 - val_loss: 1.8229 - val_acc: 0.3961
# Epoch 4/10
# 50000/50000 [==============================] - 5s 103us/step - loss: 1.5349 - acc: 0.5016 - val_loss: 1.7563 - val_acc: 0.4175
# Epoch 5/10
# 50000/50000 [==============================] - 5s 102us/step - loss: 1.4876 - acc: 0.5184 - val_loss: 1.8270 - val_acc: 0.4158
# Epoch 6/10
# 50000/50000 [==============================] - 5s 105us/step - loss: 1.4553 - acc: 0.5323 - val_loss: 1.7375 - val_acc: 0.4259
# Epoch 7/10
# 50000/50000 [==============================] - 5s 104us/step - loss: 1.4225 - acc: 0.5470 - val_loss: 1.8685 - val_acc: 0.3888
# Epoch 8/10
# 50000/50000 [==============================] - 5s 105us/step - loss: 1.3952 - acc: 0.5547 - val_loss: 1.7763 - val_acc: 0.4142
# Epoch 9/10
# 50000/50000 [==============================] - 5s 105us/step - loss: 1.3788 - acc: 0.5640 - val_loss: 1.6643 - val_acc: 0.4662
# Epoch 10/10
# 50000/50000 [==============================] - 5s 106us/step - loss: 1.3567 - acc: 0.5726 - val_loss: 1.7764 - val_acc: 0.4151
# Numbers of exp: 6, with bn: True, drp_ratio: 0.40, l2_ratio: 0.00
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# activation_1 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_2 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# activation_3 (Activation)    (None, 128)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 6s 111us/step - loss: 1.9784 - acc: 0.3017 - val_loss: 1.8108 - val_acc: 0.3452
# Epoch 2/10
# 50000/50000 [==============================] - 5s 98us/step - loss: 1.7070 - acc: 0.3865 - val_loss: 1.6603 - val_acc: 0.4116
# Epoch 3/10
# 50000/50000 [==============================] - 5s 97us/step - loss: 1.6032 - acc: 0.4262 - val_loss: 1.6531 - val_acc: 0.4096
# Epoch 4/10
# 50000/50000 [==============================] - 5s 97us/step - loss: 1.5434 - acc: 0.4495 - val_loss: 1.7798 - val_acc: 0.3606
# Epoch 5/10
# 50000/50000 [==============================] - 5s 98us/step - loss: 1.4931 - acc: 0.4691 - val_loss: 1.5056 - val_acc: 0.4683
# Epoch 6/10
# 50000/50000 [==============================] - 5s 97us/step - loss: 1.4648 - acc: 0.4762 - val_loss: 1.5793 - val_acc: 0.4277
# Epoch 7/10
# 50000/50000 [==============================] - 5s 97us/step - loss: 1.4294 - acc: 0.4901 - val_loss: 1.5164 - val_acc: 0.4704
# Epoch 8/10
# 50000/50000 [==============================] - 5s 96us/step - loss: 1.3996 - acc: 0.5006 - val_loss: 1.5496 - val_acc: 0.4353
# Epoch 9/10
# 50000/50000 [==============================] - 5s 94us/step - loss: 1.3678 - acc: 0.5146 - val_loss: 1.6146 - val_acc: 0.4106
# Epoch 10/10
# 50000/50000 [==============================] - 5s 91us/step - loss: 1.3515 - acc: 0.5188 - val_loss: 1.5529 - val_acc: 0.4355
# Numbers of exp: 7, with bn: True, drp_ratio: 0.40, l2_ratio: 0.01
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# activation_1 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_2 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# activation_3 (Activation)    (None, 128)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 6s 124us/step - loss: 6.3030 - acc: 0.2926 - val_loss: 3.1768 - val_acc: 0.1951
# Epoch 2/10
# 50000/50000 [==============================] - 5s 106us/step - loss: 2.4935 - acc: 0.3551 - val_loss: 2.4973 - val_acc: 0.2737
# Epoch 3/10
# 50000/50000 [==============================] - 5s 106us/step - loss: 2.1909 - acc: 0.3727 - val_loss: 2.3834 - val_acc: 0.2700
# Epoch 4/10
# 50000/50000 [==============================] - 5s 105us/step - loss: 2.1300 - acc: 0.3767 - val_loss: 2.5719 - val_acc: 0.2398
# Epoch 5/10
# 50000/50000 [==============================] - 5s 106us/step - loss: 2.1185 - acc: 0.3747 - val_loss: 2.6581 - val_acc: 0.2106
# Epoch 6/10
# 50000/50000 [==============================] - 5s 106us/step - loss: 2.1186 - acc: 0.3765 - val_loss: 2.4720 - val_acc: 0.2240
# Epoch 7/10
# 50000/50000 [==============================] - 5s 103us/step - loss: 2.1218 - acc: 0.3736 - val_loss: 2.4151 - val_acc: 0.2547
# Epoch 8/10
# 50000/50000 [==============================] - 5s 105us/step - loss: 2.1183 - acc: 0.3791 - val_loss: 2.4567 - val_acc: 0.2278
# Epoch 9/10
# 50000/50000 [==============================] - 5s 104us/step - loss: 2.1207 - acc: 0.3781 - val_loss: 2.3685 - val_acc: 0.2566
# Epoch 10/10
# 50000/50000 [==============================] - 5s 100us/step - loss: 2.1179 - acc: 0.3777 - val_loss: 2.4080 - val_acc: 0.2380
# Numbers of exp: 8, with bn: True, drp_ratio: 0.40, l2_ratio: 0.00
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# activation_1 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_2 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# activation_3 (Activation)    (None, 128)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 6s 122us/step - loss: 2.1529 - acc: 0.2969 - val_loss: 1.9306 - val_acc: 0.3577
# Epoch 2/10
# 50000/50000 [==============================] - 5s 105us/step - loss: 1.8594 - acc: 0.3851 - val_loss: 1.9072 - val_acc: 0.3591
# Epoch 3/10
# 50000/50000 [==============================] - 5s 104us/step - loss: 1.7551 - acc: 0.4217 - val_loss: 1.9036 - val_acc: 0.3593
# Epoch 4/10
# 50000/50000 [==============================] - 5s 104us/step - loss: 1.6931 - acc: 0.4445 - val_loss: 1.7850 - val_acc: 0.4064
# Epoch 5/10
# 50000/50000 [==============================] - 5s 104us/step - loss: 1.6510 - acc: 0.4612 - val_loss: 1.8834 - val_acc: 0.3890
# Epoch 6/10
# 50000/50000 [==============================] - 5s 106us/step - loss: 1.6178 - acc: 0.4720 - val_loss: 1.7263 - val_acc: 0.4482
# Epoch 7/10
# 50000/50000 [==============================] - 5s 104us/step - loss: 1.5865 - acc: 0.4829 - val_loss: 1.8105 - val_acc: 0.3992
# Epoch 8/10
# 50000/50000 [==============================] - 5s 104us/step - loss: 1.5679 - acc: 0.4928 - val_loss: 1.8192 - val_acc: 0.3865
# Epoch 9/10
# 50000/50000 [==============================] - 5s 106us/step - loss: 1.5511 - acc: 0.4986 - val_loss: 1.7273 - val_acc: 0.4526
# Epoch 10/10
# 50000/50000 [==============================] - 5s 106us/step - loss: 1.5305 - acc: 0.5065 - val_loss: 1.7304 - val_acc: 0.4380
# Numbers of exp: 9, with bn: False, drp_ratio: 0.00, l2_ratio: 0.00
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# activation_1 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# activation_2 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# activation_3 (Activation)    (None, 128)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 4s 88us/step - loss: 1.9373 - acc: 0.3009 - val_loss: 1.7718 - val_acc: 0.3684
# Epoch 2/10
# 50000/50000 [==============================] - 4s 80us/step - loss: 1.7068 - acc: 0.3912 - val_loss: 1.6512 - val_acc: 0.4088
# Epoch 3/10
# 50000/50000 [==============================] - 4s 81us/step - loss: 1.6122 - acc: 0.4246 - val_loss: 1.5830 - val_acc: 0.4399
# Epoch 4/10
# 50000/50000 [==============================] - 4s 80us/step - loss: 1.5478 - acc: 0.4492 - val_loss: 1.5474 - val_acc: 0.4504
# Epoch 5/10
# 50000/50000 [==============================] - 4s 79us/step - loss: 1.5054 - acc: 0.4632 - val_loss: 1.5120 - val_acc: 0.4581
# Epoch 6/10
# 50000/50000 [==============================] - 4s 76us/step - loss: 1.4669 - acc: 0.4749 - val_loss: 1.4646 - val_acc: 0.4793
# Epoch 7/10
# 50000/50000 [==============================] - 4s 76us/step - loss: 1.4412 - acc: 0.4855 - val_loss: 1.5109 - val_acc: 0.4602
# Epoch 8/10
# 50000/50000 [==============================] - 4s 79us/step - loss: 1.4083 - acc: 0.4980 - val_loss: 1.5043 - val_acc: 0.4667
# Epoch 9/10
# 50000/50000 [==============================] - 4s 80us/step - loss: 1.3858 - acc: 0.5075 - val_loss: 1.4932 - val_acc: 0.4669
# Epoch 10/10
# 50000/50000 [==============================] - 4s 74us/step - loss: 1.3525 - acc: 0.5178 - val_loss: 1.4561 - val_acc: 0.4842
# Numbers of exp: 10, with bn: False, drp_ratio: 0.00, l2_ratio: 0.01
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# activation_1 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# activation_2 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# activation_3 (Activation)    (None, 128)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 5s 90us/step - loss: 4.9803 - acc: 0.2800 - val_loss: 2.5431 - val_acc: 0.3180
# Epoch 2/10
# 50000/50000 [==============================] - 4s 85us/step - loss: 2.3165 - acc: 0.3311 - val_loss: 2.1989 - val_acc: 0.3333
# Epoch 3/10
# 50000/50000 [==============================] - 4s 85us/step - loss: 2.0918 - acc: 0.3531 - val_loss: 2.0544 - val_acc: 0.3353
# Epoch 4/10
# 50000/50000 [==============================] - 4s 84us/step - loss: 2.0127 - acc: 0.3536 - val_loss: 1.9615 - val_acc: 0.3739
# Epoch 5/10
# 50000/50000 [==============================] - 4s 85us/step - loss: 1.9490 - acc: 0.3653 - val_loss: 2.0411 - val_acc: 0.3339
# Epoch 6/10
# 50000/50000 [==============================] - 4s 82us/step - loss: 1.9124 - acc: 0.3730 - val_loss: 1.8882 - val_acc: 0.3796
# Epoch 7/10
# 50000/50000 [==============================] - 4s 86us/step - loss: 1.8866 - acc: 0.3775 - val_loss: 1.8774 - val_acc: 0.3808
# Epoch 8/10
# 50000/50000 [==============================] - 4s 89us/step - loss: 1.8767 - acc: 0.3820 - val_loss: 1.8807 - val_acc: 0.3828
# Epoch 9/10
# 50000/50000 [==============================] - 4s 88us/step - loss: 1.8632 - acc: 0.3862 - val_loss: 1.8325 - val_acc: 0.4036
# Epoch 10/10
# 50000/50000 [==============================] - 4s 89us/step - loss: 1.8458 - acc: 0.3902 - val_loss: 1.8026 - val_acc: 0.4031
# Numbers of exp: 11, with bn: False, drp_ratio: 0.00, l2_ratio: 0.00
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# activation_1 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# activation_2 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# activation_3 (Activation)    (None, 128)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 5s 95us/step - loss: 2.0418 - acc: 0.2974 - val_loss: 1.8988 - val_acc: 0.3426
# Epoch 2/10
# 50000/50000 [==============================] - 4s 87us/step - loss: 1.7858 - acc: 0.3860 - val_loss: 1.7629 - val_acc: 0.3974
# Epoch 3/10
# 50000/50000 [==============================] - 4s 83us/step - loss: 1.6740 - acc: 0.4228 - val_loss: 1.6303 - val_acc: 0.4471
# Epoch 4/10
# 50000/50000 [==============================] - 4s 82us/step - loss: 1.6037 - acc: 0.4460 - val_loss: 1.5761 - val_acc: 0.4534
# Epoch 5/10
# 50000/50000 [==============================] - 4s 87us/step - loss: 1.5502 - acc: 0.4657 - val_loss: 1.5650 - val_acc: 0.4607
# Epoch 6/10
# 50000/50000 [==============================] - 4s 83us/step - loss: 1.5107 - acc: 0.4769 - val_loss: 1.5657 - val_acc: 0.4574
# Epoch 7/10
# 50000/50000 [==============================] - 4s 88us/step - loss: 1.4763 - acc: 0.4915 - val_loss: 1.5080 - val_acc: 0.4758
# Epoch 8/10
# 50000/50000 [==============================] - 5s 93us/step - loss: 1.4586 - acc: 0.4962 - val_loss: 1.4956 - val_acc: 0.4836
# Epoch 9/10
# 50000/50000 [==============================] - 5s 100us/step - loss: 1.4329 - acc: 0.5069 - val_loss: 1.5009 - val_acc: 0.4790
# Epoch 10/10
# 50000/50000 [==============================] - 5s 97us/step - loss: 1.4169 - acc: 0.5128 - val_loss: 1.5098 - val_acc: 0.4840
# Numbers of exp: 12, with bn: False, drp_ratio: 0.20, l2_ratio: 0.00
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# activation_1 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# activation_2 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# activation_3 (Activation)    (None, 128)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 5s 98us/step - loss: 2.0433 - acc: 0.2479 - val_loss: 1.7958 - val_acc: 0.3457
# Epoch 2/10
# 50000/50000 [==============================] - 4s 88us/step - loss: 1.8409 - acc: 0.3344 - val_loss: 1.7494 - val_acc: 0.3646
# Epoch 3/10
# 50000/50000 [==============================] - 5s 97us/step - loss: 1.7885 - acc: 0.3560 - val_loss: 1.6718 - val_acc: 0.4019
# Epoch 4/10
# 50000/50000 [==============================] - 4s 87us/step - loss: 1.7443 - acc: 0.3726 - val_loss: 1.6361 - val_acc: 0.4210
# Epoch 5/10
# 50000/50000 [==============================] - 4s 86us/step - loss: 1.7016 - acc: 0.3873 - val_loss: 1.5972 - val_acc: 0.4261
# Epoch 6/10
# 50000/50000 [==============================] - 4s 80us/step - loss: 1.6744 - acc: 0.3968 - val_loss: 1.5993 - val_acc: 0.4305
# Epoch 7/10
# 50000/50000 [==============================] - 4s 79us/step - loss: 1.6588 - acc: 0.4026 - val_loss: 1.5724 - val_acc: 0.4365
# Epoch 8/10
# 50000/50000 [==============================] - 4s 86us/step - loss: 1.6400 - acc: 0.4091 - val_loss: 1.5467 - val_acc: 0.4546
# Epoch 9/10
# 50000/50000 [==============================] - 4s 90us/step - loss: 1.6252 - acc: 0.4161 - val_loss: 1.5497 - val_acc: 0.4485
# Epoch 10/10
# 50000/50000 [==============================] - 4s 86us/step - loss: 1.6082 - acc: 0.4206 - val_loss: 1.5388 - val_acc: 0.4607
# Numbers of exp: 13, with bn: False, drp_ratio: 0.20, l2_ratio: 0.01
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# activation_1 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# activation_2 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# activation_3 (Activation)    (None, 128)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 5s 102us/step - loss: 4.5139 - acc: 0.2389 - val_loss: 2.2367 - val_acc: 0.3065
# Epoch 2/10
# 50000/50000 [==============================] - 5s 91us/step - loss: 2.1271 - acc: 0.3105 - val_loss: 2.0424 - val_acc: 0.3087
# Epoch 3/10
# 50000/50000 [==============================] - 5s 90us/step - loss: 2.0216 - acc: 0.3201 - val_loss: 1.9465 - val_acc: 0.3496
# Epoch 4/10
# 50000/50000 [==============================] - 4s 85us/step - loss: 1.9799 - acc: 0.3297 - val_loss: 1.9115 - val_acc: 0.3657
# Epoch 5/10
# 50000/50000 [==============================] - 4s 89us/step - loss: 1.9734 - acc: 0.3292 - val_loss: 1.8721 - val_acc: 0.3731
# Epoch 6/10
# 50000/50000 [==============================] - 4s 90us/step - loss: 1.9698 - acc: 0.3338 - val_loss: 1.8761 - val_acc: 0.3737
# Epoch 7/10
# 50000/50000 [==============================] - 4s 89us/step - loss: 1.9530 - acc: 0.3392 - val_loss: 1.9296 - val_acc: 0.3560
# Epoch 8/10
# 50000/50000 [==============================] - 4s 90us/step - loss: 1.9565 - acc: 0.3325 - val_loss: 1.8990 - val_acc: 0.3499
# Epoch 9/10
# 50000/50000 [==============================] - 4s 88us/step - loss: 1.9510 - acc: 0.3346 - val_loss: 1.8665 - val_acc: 0.3658
# Epoch 10/10
# 50000/50000 [==============================] - 4s 88us/step - loss: 1.9578 - acc: 0.3326 - val_loss: 1.8729 - val_acc: 0.3739
# Numbers of exp: 14, with bn: False, drp_ratio: 0.20, l2_ratio: 0.00
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# activation_1 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# activation_2 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# activation_3 (Activation)    (None, 128)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 5s 103us/step - loss: 2.1387 - acc: 0.2519 - val_loss: 1.9215 - val_acc: 0.3459
# Epoch 2/10
# 50000/50000 [==============================] - 5s 94us/step - loss: 1.9197 - acc: 0.3323 - val_loss: 1.8149 - val_acc: 0.3739
# Epoch 3/10
# 50000/50000 [==============================] - 5s 94us/step - loss: 1.8389 - acc: 0.3582 - val_loss: 1.7305 - val_acc: 0.4068
# Epoch 4/10
# 50000/50000 [==============================] - 5s 94us/step - loss: 1.7893 - acc: 0.3712 - val_loss: 1.6800 - val_acc: 0.4281
# Epoch 5/10
# 50000/50000 [==============================] - 5s 91us/step - loss: 1.7406 - acc: 0.3867 - val_loss: 1.6578 - val_acc: 0.4277
# Epoch 6/10
# 50000/50000 [==============================] - 5s 93us/step - loss: 1.7111 - acc: 0.3961 - val_loss: 1.6237 - val_acc: 0.4421
# Epoch 7/10
# 50000/50000 [==============================] - 5s 91us/step - loss: 1.6919 - acc: 0.4039 - val_loss: 1.5892 - val_acc: 0.4487
# Epoch 8/10
# 50000/50000 [==============================] - 5s 90us/step - loss: 1.6598 - acc: 0.4148 - val_loss: 1.6065 - val_acc: 0.4409
# Epoch 9/10
# 50000/50000 [==============================] - 5s 93us/step - loss: 1.6454 - acc: 0.4193 - val_loss: 1.5730 - val_acc: 0.4583
# Epoch 10/10
# 50000/50000 [==============================] - 5s 92us/step - loss: 1.6426 - acc: 0.4247 - val_loss: 1.5954 - val_acc: 0.4540
# Numbers of exp: 15, with bn: False, drp_ratio: 0.40, l2_ratio: 0.00
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# activation_1 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# activation_2 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# activation_3 (Activation)    (None, 128)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 5s 90us/step - loss: 2.1546 - acc: 0.1926 - val_loss: 1.9347 - val_acc: 0.2811
# Epoch 2/10
# 50000/50000 [==============================] - 4s 85us/step - loss: 2.0058 - acc: 0.2454 - val_loss: 1.9051 - val_acc: 0.3129
# Epoch 3/10
# 50000/50000 [==============================] - 4s 85us/step - loss: 1.9564 - acc: 0.2667 - val_loss: 1.8743 - val_acc: 0.3335
# Epoch 4/10
# 50000/50000 [==============================] - 4s 86us/step - loss: 1.9431 - acc: 0.2722 - val_loss: 1.8716 - val_acc: 0.3379
# Epoch 5/10
# 50000/50000 [==============================] - 4s 86us/step - loss: 1.9146 - acc: 0.2878 - val_loss: 1.8321 - val_acc: 0.3442
# Epoch 6/10
# 50000/50000 [==============================] - 4s 86us/step - loss: 1.9000 - acc: 0.2952 - val_loss: 1.8279 - val_acc: 0.3567
# Epoch 7/10
# 50000/50000 [==============================] - 4s 86us/step - loss: 1.8896 - acc: 0.3029 - val_loss: 1.8272 - val_acc: 0.3453
# Epoch 8/10
# 50000/50000 [==============================] - 4s 86us/step - loss: 1.8789 - acc: 0.3057 - val_loss: 1.8189 - val_acc: 0.3536
# Epoch 9/10
# 50000/50000 [==============================] - 4s 85us/step - loss: 1.8734 - acc: 0.3071 - val_loss: 1.8039 - val_acc: 0.3645
# Epoch 10/10
# 50000/50000 [==============================] - 4s 86us/step - loss: 1.8573 - acc: 0.3140 - val_loss: 1.8489 - val_acc: 0.3372
# Numbers of exp: 16, with bn: False, drp_ratio: 0.40, l2_ratio: 0.01
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# activation_1 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# activation_2 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# activation_3 (Activation)    (None, 128)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 5s 104us/step - loss: 4.8910 - acc: 0.1909 - val_loss: 2.2836 - val_acc: 0.2976
# Epoch 2/10
# 50000/50000 [==============================] - 5s 94us/step - loss: 2.1972 - acc: 0.2556 - val_loss: 2.1021 - val_acc: 0.2874
# Epoch 3/10
# 50000/50000 [==============================] - 5s 93us/step - loss: 2.0926 - acc: 0.2687 - val_loss: 1.9770 - val_acc: 0.3312
# Epoch 4/10
# 50000/50000 [==============================] - 5s 94us/step - loss: 2.0683 - acc: 0.2772 - val_loss: 1.9713 - val_acc: 0.3254
# Epoch 5/10
# 50000/50000 [==============================] - 5s 93us/step - loss: 2.0701 - acc: 0.2721 - val_loss: 2.0061 - val_acc: 0.3206
# Epoch 6/10
# 50000/50000 [==============================] - 5s 94us/step - loss: 2.0732 - acc: 0.2682 - val_loss: 1.9962 - val_acc: 0.3101
# Epoch 7/10
# 50000/50000 [==============================] - 5s 93us/step - loss: 2.0645 - acc: 0.2734 - val_loss: 2.0146 - val_acc: 0.3116
# Epoch 8/10
# 50000/50000 [==============================] - 5s 94us/step - loss: 2.0644 - acc: 0.2710 - val_loss: 1.9675 - val_acc: 0.3171
# Epoch 9/10
# 50000/50000 [==============================] - 5s 93us/step - loss: 2.0614 - acc: 0.2649 - val_loss: 2.0065 - val_acc: 0.3061
# Epoch 10/10
# 50000/50000 [==============================] - 5s 92us/step - loss: 2.0601 - acc: 0.2660 - val_loss: 1.9326 - val_acc: 0.3302
# Numbers of exp: 17, with bn: False, drp_ratio: 0.40, l2_ratio: 0.00
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# activation_1 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# activation_2 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# activation_3 (Activation)    (None, 128)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 5s 105us/step - loss: 2.2862 - acc: 0.1846 - val_loss: 2.0714 - val_acc: 0.2901
# Epoch 2/10
# 50000/50000 [==============================] - 5s 95us/step - loss: 2.0985 - acc: 0.2409 - val_loss: 1.9842 - val_acc: 0.3015
# Epoch 3/10
# 50000/50000 [==============================] - 5s 94us/step - loss: 2.0256 - acc: 0.2700 - val_loss: 1.9279 - val_acc: 0.3330
# Epoch 4/10
# 50000/50000 [==============================] - 5s 91us/step - loss: 1.9831 - acc: 0.2819 - val_loss: 1.9063 - val_acc: 0.3473
# Epoch 5/10
# 50000/50000 [==============================] - 5s 91us/step - loss: 1.9532 - acc: 0.2898 - val_loss: 1.8867 - val_acc: 0.3655
# Epoch 6/10
# 50000/50000 [==============================] - 5s 95us/step - loss: 1.9382 - acc: 0.2973 - val_loss: 1.8739 - val_acc: 0.3614
# Epoch 7/10
# 50000/50000 [==============================] - 5s 94us/step - loss: 1.9139 - acc: 0.3041 - val_loss: 1.8614 - val_acc: 0.3633
# Epoch 8/10
# 50000/50000 [==============================] - 5s 99us/step - loss: 1.9038 - acc: 0.3063 - val_loss: 1.8492 - val_acc: 0.3447
# Epoch 9/10
# 50000/50000 [==============================] - 6s 115us/step - loss: 1.8911 - acc: 0.3129 - val_loss: 1.8544 - val_acc: 0.3463
# Epoch 10/10
# 50000/50000 [==============================] - 5s 99us/step - loss: 1.8759 - acc: 0.3198 - val_loss: 1.8211 - val_acc: 0.3659

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import matplotlib.cm as mplcm
import matplotlib.colors as colors
"""Code Here
將結果繪出
"""
NUM_COLORS = 20

cm = plt.get_cmap('gist_rainbow')
cNorm  = colors.Normalize(vmin=0, vmax=NUM_COLORS-1)
scalarMap = mplcm.ScalarMappable(norm=cNorm, cmap=cm)
color_bar = [scalarMap.to_rgba(i) for i in range(NUM_COLORS)]

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-loss'])),results[cond]['train-loss'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-loss'])),results[cond]['valid-loss'], '--', label=cond, color=color_bar[i])
plt.title("Loss")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-acc'])),results[cond]['train-acc'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-acc'])),results[cond]['valid-acc'], '--', label=cond, color=color_bar[i])
plt.title("Accuracy")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()
